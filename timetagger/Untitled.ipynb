# %%
# %pylab notebook
import time
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fig, ax = subplots(1, 1)

x = linspace(0, 1, 100)

line, = ax.plot(x, ones_like(x))

ylim(-1.5, 1.5)
# Out:
# <img src="data:image/png;base64,..." width="639.6135471974932">
# (-1.5, 1.5)

# %%
for i in range(100):
    y = cos(x + i / 10.)
    line.set_ydata(y)
    fig.canvas.draw()
    time.sleep(.05)
